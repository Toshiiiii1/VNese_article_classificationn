# %%
! pip install underthesea
# Out:
# Collecting underthesea
#   Downloading underthesea-6.8.0-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: Click>=6.0 in /opt/conda/lib/python3.10/site-packages (from underthesea) (8.1.7)
# Collecting python-crfsuite>=0.9.6 (from underthesea)
#   Downloading python_crfsuite-0.9.10-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.2 kB)
# Requirement already satisfied: nltk in /opt/conda/lib/python3.10/site-packages (from underthesea) (3.2.4)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from underthesea) (4.66.1)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from underthesea) (2.31.0)
# Requirement already satisfied: joblib in /opt/conda/lib/python3.10/site-packages (from underthesea) (1.3.2)
# Requirement already satisfied: scikit-learn in /opt/conda/lib/python3.10/site-packages (from underthesea) (1.2.2)
# Requirement already satisfied: PyYAML in /opt/conda/lib/python3.10/site-packages (from underthesea) (6.0.1)
# Collecting underthesea-core==1.0.4 (from underthesea)
#   Downloading underthesea_core-1.0.4-cp310-cp310-manylinux2010_x86_64.whl.metadata (1.7 kB)
# Requirement already satisfied: six in /opt/conda/lib/python3.10/site-packages (from nltk->underthesea) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->underthesea) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->underthesea) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->underthesea) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->underthesea) (2024.2.2)
# Requirement already satisfied: numpy>=1.17.3 in /opt/conda/lib/python3.10/site-packages (from scikit-learn->underthesea) (1.26.4)
# Requirement already satisfied: scipy>=1.3.2 in /opt/conda/lib/python3.10/site-packages (from scikit-learn->underthesea) (1.11.4)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn->underthesea) (3.2.0)
# Downloading underthesea-6.8.0-py3-none-any.whl (20.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.9/20.9 MB 71.0 MB/s eta 0:00:00:00:0100:01
# Downloading underthesea_core-1.0.4-cp310-cp310-manylinux2010_x86_64.whl (657 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 657.8/657.8 kB 29.5 MB/s eta 0:00:00
# Downloading python_crfsuite-0.9.10-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 46.6 MB/s eta 0:00:00
# Installing collected packages: underthesea-core, python-crfsuite, underthesea
# Successfully installed python-crfsuite-0.9.10 underthesea-6.8.0 underthesea-core-1.0.4

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
import numpy as np
import pandas as pd
from underthesea import word_tokenize
from sklearn.model_selection import train_test_split
import pickle

# %% [markdown]
# Load data

# %%
train_set = pd.read_csv("/kaggle/input/vnese-articles/train_set.csv").astype("str")

X, y = train_set["article"], train_set["label"]

train_set.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10253 entries, 0 to 10252
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   article  10253 non-null  object
#  1   label    10253 non-null  object
# dtypes: object(2)
# memory usage: 160.3+ KB

# %% [markdown]
# Define a list of stop words

# %%
with open("/kaggle/input/vnese-articles/vietnamese-stopwords-dash.txt", "r") as f:
    stop_words = f.readlines()
    stop_words = [stop_word.strip() for stop_word in stop_words]
print(stop_words[:10])
# Out:
# ['a_lô', 'a_ha', 'ai', 'ai_ai', 'ai_nấy', 'ai_đó', 'alô', 'amen', 'anh', 'anh_ấy']

# %%
X = X.apply(lambda x : word_tokenize(x, format="text"))
print(X)
# Out:
# 0        một khoảnh_khắc thiên_nhiên kỳ_thú được các du...
# 1        hoa_hậu lê_hoàng_phương hóa hằng nga trai đẹp ...
# 2        giá vàng nhẫn_k liên_tục lập_đỉnh mới có nơi b...
# 3        hôm_nay ban kỷ_luật liên_đoàn bóng_đá việt_nam...
# 4        mỹ vừa tiến_hành các biện_pháp nặng cân nhằm t...
#                                ...
# 10248    lãnh_đạo huyện nói theo hình_ảnh từ camera cô_...
# 10249    bên dưới nền_móng lịch_sử của lâu_đài cổ_zerze...
# 10250    năm_học tình_trạng giáo_viên thừa thiếu cục_bộ...
# 10251    là một trong thành_trì được xây_dựng thời nhà ...
# 10252    phim chúng_ta của năm sau tập tiểu_tam đến tận...
# Name: article, Length: 10253, dtype: object

# %% [markdown]
# Convert text to BOW

# %%
train_countvectorizer = TfidfVectorizer(stop_words=stop_words, max_features=10000)

X_BOW = train_countvectorizer.fit_transform(X)
vocabulary = train_countvectorizer.vocabulary_
print(len(vocabulary.items()))

pickle.dump(vocabulary, open("/kaggle/working/vocabulary.pkl", 'wb'))
# Out:
# 10000

# %%
X_train, X_test, y_train, y_test = train_test_split(X_BOW, y, random_state=42, test_size=0.1)

print(X_train.shape)
print(X_test.shape)
# Out:
# (9227, 10000)
# (1026, 10000)

# %%
max_value = X_BOW.max(axis=0).toarray().ravel()
sorted_by_tfidf = max_value.argsort()
feature_names = np.array(train_countvectorizer.get_feature_names_out())

print("Features with lowest tfidf:\n{}".format(feature_names[sorted_by_tfidf[:20]]))
print("Features with highest tfidf: \n{}".format(feature_names[sorted_by_tfidf[-20:]]))
# Out:
# Features with lowest tfidf:
# ['quyết_đấu' 'quân_tuổi' 'cội_nguồn' 'cảm_kích' 'dũng_mãnh' 'rặng' 'hòng'
#  'lạnh_lùng' 'lựa' 'quyết_đoán' 'rong_ruổi' 'gắt_gao' 'bảo_chứng'
#  'duyên_nợ' 'quý_phú_nhuận' 'bà_trương' 'nhiệt_thành' 'tổng_quan' 'dù_vậy'
#  'thương_lượng']
# Features with highest tfidf:
# ['quảng_ngãi' 'smartwatch' 'windows' 'cụ' 'sinner' 'hát_lý' 'angelababy'
#  'đen' 'jolie' 'lightstick' 'twice' 'acbs' 'gấu_trúc' 'hiền_hồ' 'gà'
#  'bánh_mì' 'lưu_bích' 'tào_tháo' 'nokia' 'hắn']

# %% [markdown]
# Naive Bayes

# %%
from sklearn.model_selection import cross_val_score
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import f1_score, accuracy_score

scores = cross_val_score(MultinomialNB(), X_train, y_train, cv=10)
print("Mean cross-validation accuracy: {:.2f}".format(np.mean(scores)))

model = MultinomialNB()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
print(f"Accuracy: {accuracy_score(y_test, y_pred)}")
print(f"F1: {f1_score(y_test, y_pred, average='micro')}")

pickle.dump(model, open("/kaggle/working/bayes_model.pkl", 'wb'))
# Out:
# Mean cross-validation accuracy: 0.83
# Accuracy: 0.8255360623781677
# F1: 0.8255360623781677

# %% [markdown]
# Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier

scores = cross_val_score(DecisionTreeClassifier(), X_train, y_train, cv=10)
print("Mean cross-validation accuracy: {:.2f}".format(np.mean(scores)))

model = DecisionTreeClassifier()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
print(f"Accuracy: {accuracy_score(y_test, y_pred)}")
print(f"F1: {f1_score(y_test, y_pred, average='micro')}")
# Out:
# Mean cross-validation accuracy: 0.59
# Accuracy: 0.6045831301803998
# F1: 0.6045831301803998

# %% [markdown]
# SVM

# %%
from sklearn.svm import SVC

scores = cross_val_score(SVC(C=10, gamma=1e-5), X_train, y_train, cv=10)
print("Mean cross-validation accuracy: {:.2f}".format(np.mean(scores)))

model = SVC(C=10, gamma=1e-5)
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
print(f"Accuracy: {accuracy_score(y_test, y_pred)}")
print(f"F1: {f1_score(y_test, y_pred, average='micro')}")
# Out:
# Mean cross-validation accuracy: 0.10
# Accuracy: 0.10238907849829351
# F1: 0.10238907849829351

# %%
from sklearn.linear_model import LogisticRegression

scores = cross_val_score(LogisticRegression(), X_train, y_train, cv=10)
print("Mean cross-validation accuracy: {:.2f}".format(np.mean(scores)))

model = LogisticRegression()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
print(f"Accuracy: {accuracy_score(y_test, y_pred)}")
print(f"F1: {f1_score(y_test, y_pred, average='micro')}")
# Out:
# Mean cross-validation accuracy: 0.83
# Accuracy: 0.8186250609458801
# F1: 0.81862506094588

# %%
from sklearn.ensemble import RandomForestClassifier

scores = cross_val_score(RandomForestClassifier(n_estimators=10), X_train, y_train, cv=10)
print("Mean cross-validation accuracy: {:.2f}".format(np.mean(scores)))

model = RandomForestClassifier(n_estimators=10)
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
print(f"Accuracy: {accuracy_score(y_test, y_pred)}")
print(f"F1: {f1_score(y_test, y_pred, average='micro')}")
# Out:
# Mean cross-validation accuracy: 0.65
# Accuracy: 0.6704046806435885
# F1: 0.6704046806435885

# %%
from sklearn.ensemble import GradientBoostingClassifier

scores = cross_val_score(GradientBoostingClassifier(n_estimators=10), X_train, y_train, cv=10)
print("Mean cross-validation accuracy: {:.2f}".format(np.mean(scores)))

model = GradientBoostingClassifier(n_estimators=10)
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
print(f"Accuracy: {accuracy_score(y_test, y_pred)}")
print(f"F1: {f1_score(y_test, y_pred, average='micro')}")
# Out:
# Mean cross-validation accuracy: 0.75
# Accuracy: 0.7450024378352024
# F1: 0.7450024378352024

# %% [markdown]
# Neural Network

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout

# Khởi tạo mô hình Sequential
model = Sequential()

# Thêm tầng ẩn đầu tiên với 128 units và hàm kích hoạt là ReLU
model.add(Dense(8, input_shape=(10000 ,), activation='relu'))

model.add(Dropout(0.2))

# Thêm tầng đầu ra với số units bằng số lớp và hàm kích hoạt là softmax (vì đây là bài toán phân loại)
model.add(Dense(10, activation='softmax'))

# Biên dịch mô hình với hàm mất mát là categorical_crossentropy (do đây là bài toán phân loại) và tối ưu hóa là adam
model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# In ra tóm tắt của mô hình
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_2 (Dense)                 │ (None, 8)              │        80,008 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 8)              │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 10)             │            90 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 80,098 (312.88 KB)
#  Trainable params: 80,098 (312.88 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.fit(
    x=X_train.toarray(),
    y=y_train.astype("float32"),
    epochs=30,
    batch_size=64,
    validation_split=0.2
)

model.save("/kaggle/working/nn_model.h5")
# Out:
# Epoch 1/30
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.3124 - loss: 2.2434 - val_accuracy: 0.5726 - val_loss: 1.9988
# Epoch 2/30
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5298 - loss: 1.8942 - val_accuracy: 0.6831 - val_loss: 1.5988
# Epoch 3/30
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6060 - loss: 1.5285 - val_accuracy: 0.7254 - val_loss: 1.2698
# Epoch 4/30
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6567 - loss: 1.2328 - val_accuracy: 0.7633 - val_loss: 1.0466
# Epoch 5/30
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6784 - loss: 1.0706 - val_accuracy: 0.7882 - val_loss: 0.9009
# Epoch 6/30
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7095 - loss: 0.9590 - val_accuracy: 0.8093 - val_loss: 0.8009
# Epoch 7/30
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7298 - loss: 0.8589 - val_accuracy: 0.8158 - val_loss: 0.7300
# Epoch 8/30
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7397 - loss: 0.8077 - val_accuracy: 0.8207 - val_loss: 0.6773
# Epoch 9/30
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7440 - loss: 0.7618 - val_accuracy: 0.8245 - val_loss: 0.6364
# Epoch 10/30
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7558 - loss: 0.7137 - val_accuracy: 0.8272 - val_loss: 0.6050
# Epoch 11/30
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7721 - loss: 0.6635 - val_accuracy: 0.8245 - val_loss: 0.5784
# Epoch 12/30
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7664 - loss: 0.6503 - val_accuracy: 0.8272 - val_loss: 0.5589
# Epoch 13/30
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7740 - loss: 0.6144 - val_accuracy: 0.8283 - val_loss: 0.5404
# Epoch 14/30
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7887 - loss: 0.5845 - val_accuracy: 0.8288 - val_loss: 0.5279
# Epoch 15/30
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7837 - loss: 0.5704 - val_accuracy: 0.8299 - val_loss: 0.5158
# Epoch 16/30
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7877 - loss: 0.5510 - val_accuracy: 0.8283 - val_loss: 0.5081
# Epoch 17/30
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7906 - loss: 0.5584 - val_accuracy: 0.8299 - val_loss: 0.4977
# Epoch 18/30
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8139 - loss: 0.5001 - val_accuracy: 0.8288 - val_loss: 0.4884
# Epoch 19/30
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8128 - loss: 0.4936 - val_accuracy: 0.8277 - val_loss: 0.4834
# Epoch 20/30
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8092 - loss: 0.4924 - val_accuracy: 0.8272 - val_loss: 0.4767
# Epoch 21/30
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8192 - loss: 0.4707 - val_accuracy: 0.8267 - val_loss: 0.4746
# Epoch 22/30
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8247 - loss: 0.4601 - val_accuracy: 0.8267 - val_loss: 0.4701
# Epoch 23/30
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8306 - loss: 0.4389 - val_accuracy: 0.8261 - val_loss: 0.4688
# Epoch 24/30
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8331 - loss: 0.4289 - val_accuracy: 0.8261 - val_loss: 0.4675
# Epoch 25/30
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8343 - loss: 0.4264 - val_accuracy: 0.8261 - val_loss: 0.4655
# Epoch 26/30
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8454 - loss: 0.4096 - val_accuracy: 0.8202 - val_loss: 0.4653
# Epoch 27/30
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8469 - loss: 0.4022 - val_accuracy: 0.8234 - val_loss: 0.4643
# Epoch 28/30
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8362 - loss: 0.4098 - val_accuracy: 0.8239 - val_loss: 0.4652
# Epoch 29/30
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8475 - loss: 0.3916 - val_accuracy: 0.8229 - val_loss: 0.4657
# Epoch 30/30
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8473 - loss: 0.3848 - val_accuracy: 0.8212 - val_loss: 0.4663

# %%
model.evaluate(
    x=X_test.toarray(),
    y=y_test.astype("float32"),
    batch_size=64
)
# Out:
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8206 - loss: 0.4950
# [0.44919195771217346, 0.8265107274055481]
